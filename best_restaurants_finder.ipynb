# %% [markdown]
# <a href="https://colab.research.google.com/github/LifeGains/AI_projects/blob/main/Best_Restaurants_Finder_(Google_Maps_API).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup

# %%
pip install googlemaps
# Out:
# Collecting googlemaps
#   Downloading googlemaps-4.10.0.tar.gz (33 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests<3.0,>=2.20.0 in /usr/local/lib/python3.10/dist-packages (from googlemaps) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.20.0->googlemaps) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.20.0->googlemaps) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.20.0->googlemaps) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.20.0->googlemaps) (2023.7.22)
# Building wheels for collected packages: googlemaps
#   Building wheel for googlemaps (setup.py) ... done
#   Created wheel for googlemaps: filename=googlemaps-4.10.0-py3-none-any.whl size=40711 sha256=6e04e0f01a05f74ea6ff4cce1ecafd6cc1c4c0848feab826d208b3b7efc57eda
#   Stored in directory: /root/.cache/pip/wheels/17/f8/79/999d5d37118fd35d7219ef57933eb9d09886c4c4503a800f84
# Successfully built googlemaps
# Installing collected packages: googlemaps
# Successfully installed googlemaps-4.10.0

# %%
pip install ppprint
# Out:
# Collecting ppprint
#   Downloading ppprint-0.1.0-py3-none-any.whl (17 kB)
# Installing collected packages: ppprint
# Successfully installed ppprint-0.1.0

# %%
import os
import googlemaps
from ppprint import ppprint
import pandas as pd
import numpy as np
import time

pd.set_option('display.float_format', lambda x: '%.2f' % x)
pd.set_option('display.max_columns', None)

# %%
# mount google drive
# ---------------------------------
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Yes you need to cd there even with the line below.
# %cd /content/drive/My\ Drive/Github/secret-api-keys
# Out:
# /content/drive/My Drive/Github/secret-api-keys

# %%
# import secret.py
import sys
import os
py_file_location = "/content/drive/My\ Drive/Github/secret-api-keys"
sys.path.append(os.path.abspath(py_file_location))
import secret

# %% [markdown]
# # Find Best Restaurants
#
# - Major Source: https://googlemaps.github.io/google-maps-services-python/docs/
#
# - Master list of Place types: https://developers.google.com/maps/documentation/places/web-service/supported_types

# %%
gmaps = googlemaps.Client(secret.apikey)

# %%
# dir(map_client)

# %% [markdown]
# Source: https://developers.google.com/maps/documentation/javascript/places
#
# Nearby Search returns a list of nearby places based on a user's location.
#
# **Text Search returns a list of nearby places based on a search string, eg. "Pizza".**
#
# Place Details requests return more detailed information about a specific place, including user reviews.

# %%
import warnings

# Set ignore_warnings to True
warnings.simplefilter("ignore")

# %%
def find_best_restaurants(city_name, place_type, min_rating=0, min_n_ratings=0, query='', n_meters=3000):
  lat = gmaps.places(query=city_name).get('results')[0].get('geometry').get('location').get('lat')
  lng = gmaps.places(query=city_name).get('results')[0].get('geometry').get('location').get('lng')
  df = pd.DataFrame()
  min_rating = min_rating
  min_n_ratings = min_n_ratings
  next_page_token_list = ['', '', '']
  # print(len(next_page_token_list))
  counter = 1

  for i in range(len(next_page_token_list)):
    parent_results = gmaps.places(location=(lat,lng),
                                  type = place_type,
                                  query = query,
                                  radius = n_meters,
                                  page_token = next_page_token_list[i],
                                  # minprice = minprice,
                                  # maxprice = maxprice
                                  )
    results = parent_results.get('results')

    for j in range(len(results)):
      if results[j].get('user_ratings_total') >= min_n_ratings and results[j].get('rating') >= min_rating:
        # df = df.concat(results[j], ignore_index=True)
        df = df.append(results[j], ignore_index=True)
    try:
      next_page_token_list[counter] = parent_results.get('next_page_token')
      print(next_page_token_list)
      counter += 1
      time.sleep(3)
    except:
      time.sleep(0)

  df = df.join(pd.json_normalize(df['geometry'])).drop('geometry',axis=1)
  df = df.sort_values(by=['rating', 'user_ratings_total'], ascending=[False, False])
  df = df[ ['name', 'rating', 'user_ratings_total'] + [ col for col in df.columns if col != ['name', 'rating', 'user_ratings_total'] ] ]
  print(len(df))
  return df

# %%
# Put the sub-city into the city_name for it to work better. Eg. Lower East Side instead of Manhattan.
find_best_restaurants(city_name='San Jose',
                      # place_type is more set in stone, has to be allowed param in google
                      place_type='restaurant',
                      min_rating=4.3,
                      min_n_ratings=100,
                      # can be park, asian, bar, etc.
                      # query='asian',
                      # radius is in meters, so 4828.02 = 3 miles.
                      n_meters =4828.02,
                      )

# Verify there are 60 results
# find_best_restaurants('morgan hill', 'restaurant')
# Out:
# ['', 'AcJnMuEY-6ve_cXjAAGQrFgPJQfKHWsbtwBtQ9w3JRdtTQdWrOqw5Fdgw6NdR2oTz41-haMIKSxCItyG3RtaK31wv1W2WLieTIOrkiVZ7uwHTZ5b2mwHUWRqy3vC8KdN0q6YtB_kEroP6qkFmHJEH_nn7h6T5uwX6FopJvboV_gKq5JDh6Wf7lgc5raoDfozIdgrV0zBfoToP_kY3ig7hTamsxKydb2nJSAhscclhtPZFrFz30SGrqIhH4tdnl9Y5S7Wt1FJggfbrugbQTiFooGByMQos7xXcGIk-e9brNUpg_LevxMwngOm510gY9KiMcZFbrtkHq4MDBI9qDEXUHK8Fg5a_poIAixNhOvtKBnC-7-BzcXxNe7gxp3w6ai4m-K3PH9V8YXd7x05cSiK0JZbeEkXHFc6vhxvbmUborBqZOn97FL9BB6ZVYglIeWfiXfe9OI', '']
# ['', 'AcJnMuEY-6ve_cXjAAGQrFgPJQfKHWsbtwBtQ9w3JRdtTQdWrOqw5Fdgw6NdR2oTz41-haMIKSxCItyG3RtaK31wv1W2WLieTIOrkiVZ7uwHTZ5b2mwHUWRqy3vC8KdN0q6YtB_kEroP6qkFmHJEH_nn7h6T5uwX6FopJvboV_gKq5JDh6Wf7lgc5raoDfozIdgrV0zBfoToP_kY3ig7hTamsxKydb2nJSAhscclhtPZFrFz30SGrqIhH4tdnl9Y5S7Wt1FJggfbrugbQTiFooGByMQos7xXcGIk-e9brNUpg_LevxMwngOm510gY9KiMcZFbrtkHq4MDBI9qDEXUHK8Fg5a_poIAixNhOvtKBnC-7-BzcXxNe7gxp3w6ai4m-K3PH9V8YXd7x05cSiK0JZbeEkXHFc6vhxvbmUborBqZOn97FL9BB6ZVYglIeWfiXfe9OI', 'AcJnMuFr22HFgVDshWE5N2YKVp1dnzCYwHTD2VhD-RxXJgcrQuPfeRT4EN8Vbe8YE6YROaEZMf0VqimZEkG0hyOi_aiQiNidC-7Rikx6FFXmYMUntOUjhI8-DXiMMhR8Kt7C2FnI_RIOJJL6xFekLvOpUMtGE0rklyj0lyB5JU9XBR2f5LipXiGCHVqC1Y3YG_-tuf5QD-Dy88N3nthvNbtuxhgHkpPoTtUNhC3WkozZuoj70reauGtS7UJnjXsVolU9b397MuE9t2g5CSxPS_nmeyUxF9A96aX3MajHVFW7ZZOnQAuSbkgP26lYuVaSHUIcZrSSGhYc91iSqVXMkC_R4ZvBgsZXKuIG9ncAu5IYpPfkS3KlyJ-WzPaFa53NE8nEzKYeVDdg2NxRbwjcyab3vFLgIZ7aCazkDq5cDDc3SCnR7v3WhEFw0Sw7wuf2M2kufdfrh0JYp3i5vEKV55N_uL4C4n7aZKiZt-IU1k2dadryvE8LJlkKqk9yWF99W-y3JNm937n_W1hs0nYTp9Scl3P9TV-Z3pZr_iezjDsRvTRAaFKCCh665Zgwl3rQit4aTHs40Opv7bDHVthAEJz2QaG24NewRgHhHkA_KWughZeTcK8U547v5J9BRG0kLCCGs3DBRIIoSVpuEExKRmiL3YW_']
# 24
#                             name  rating  user_ratings_total business_status  \
# 5           MAR Y SOL RESTAURANT    4.70                 149     OPERATIONAL
# 22        Green Lotus Restaurant    4.60                 333     OPERATIONAL
# 15    Mudai Ethiopian Restaurant    4.60                 182     OPERATIONAL
# 21              The Boiling Crab    4.50                2354     OPERATIONAL
# 1     Palermo Italian Restaurant    4.50                1116     OPERATIONAL
# 20    Minato Japanese Restaurant    4.50                 649     OPERATIONAL
# 8                Maza Restaurant    4.50                 413     OPERATIONAL
# 11     Gojo Ethiopian Restaurant    4.50                 294     OPERATIONAL
# 0       Tasso's Restaurant & Bar    4.50                 280     OPERATIONAL
# 4          Crepevine Restaurants    4.40                1357     OPERATIONAL
# 13             Karimi Restaurant    4.40                 859     OPERATIONAL
# 2        Angelou's Mexican Grill    4.40                 627     OPERATIONAL
# 9      Puro Michoacan Restaurant    4.40                 622     OPERATIONAL
# 19             Taiwan Restaurant    4.40                 588     OPERATIONAL
# 23                    Yuki Sushi    4.40                 571     OPERATIONAL
# 17                     Five Guys    4.40                 528     OPERATIONAL
# 12  Kategna Ethiopian Restaurant    4.40                 499     OPERATIONAL
# 14   TEQUILA'S TAQUERIA SAN JOSE    4.30                2049     OPERATIONAL
# 6                      Zona Rosa    4.30                 892     OPERATIONAL
# 7         Habana Cuba Restaurant    4.30                 630     OPERATIONAL
# 3         Mr. Chau's Restaurants    4.30                 348     OPERATIONAL
# 16           Pho Lynn Restaurant    4.30                 252     OPERATIONAL
# 10                        Phở Hà    4.30                 249     OPERATIONAL
# 18         Restaurante El Conrro    4.30                 216     OPERATIONAL
#
#                                  formatted_address  \
# 5        1179 E Santa Clara St, San Jose, CA 95116
# 22          1143 Story Rd #180, San Jose, CA 95122
# 15         503 W San Carlos St, San Jose, CA 95126
# 21     71 Curtner Ave Suite 20, San Jose, CA 95125
# 1             791 Auzerais Ave, San Jose, CA 95126
# 20                617 N 6th St, San Jose, CA 95112
# 8                782 N 13th St, San Jose, CA 95112
# 11        1261 W San Carlos St, San Jose, CA 95126
# 0   1530 Southwest Expy STE 10, San Jose, CA 95126
# 4        1100 Lincoln Ave #180, San Jose, CA 95125
# 13             1086 N First St, San Jose, CA 95112
# 2                  21 N 2nd St, San Jose, CA 95113
# 9                1065 S 1st St, San Jose, CA 95110
# 19            1306 Lincoln Ave, San Jose, CA 95125
# 23         1140 Lincoln Ave #8, San Jose, CA 95125
# 17    121 Curtner Ave Suite 60, San Jose, CA 95125
# 12        1663 W San Carlos St, San Jose, CA 95128
# 14              1052 Leigh Ave, San Jose, CA 95126
# 6             1411 The Alameda, San Jose, CA 95126
# 7       387 S 1st St Suite 109, San Jose, CA 95113
# 3            1608 McKee Rd #10, San Jose, CA 95116
# 16                 949 Ruff Dr, San Jose, CA 95110
# 10          951 McLaughlin Ave, San Jose, CA 95122
# 18    301 E Santa Clara St # B, San Jose, CA 95113
#
#                                                  icon icon_background_color  \
# 5   https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 22  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 15  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 21  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 1   https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 20  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 8   https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 11  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 0   https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 4   https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 13  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 2   https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 9   https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 19  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 23  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 17  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 12  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 14  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 6   https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 7   https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 3   https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 16  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 10  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 18  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
#
#                                    icon_mask_base_uri  \
# 5   https://maps.gstatic.com/mapfiles/place_api/ic...
# 22  https://maps.gstatic.com/mapfiles/place_api/ic...
# 15  https://maps.gstatic.com/mapfiles/place_api/ic...
# 21  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1   https://maps.gstatic.com/mapfiles/place_api/ic...
# 20  https://maps.gstatic.com/mapfiles/place_api/ic...
# 8   https://maps.gstatic.com/mapfiles/place_api/ic...
# 11  https://maps.gstatic.com/mapfiles/place_api/ic...
# 0   https://maps.gstatic.com/mapfiles/place_api/ic...
# 4   https://maps.gstatic.com/mapfiles/place_api/ic...
# 13  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2   https://maps.gstatic.com/mapfiles/place_api/ic...
# 9   https://maps.gstatic.com/mapfiles/place_api/ic...
# 19  https://maps.gstatic.com/mapfiles/place_api/ic...
# 23  https://maps.gstatic.com/mapfiles/place_api/ic...
# 17  https://maps.gstatic.com/mapfiles/place_api/ic...
# 12  https://maps.gstatic.com/mapfiles/place_api/ic...
# 14  https://maps.gstatic.com/mapfiles/place_api/ic...
# 6   https://maps.gstatic.com/mapfiles/place_api/ic...
# 7   https://maps.gstatic.com/mapfiles/place_api/ic...
# 3   https://maps.gstatic.com/mapfiles/place_api/ic...
# 16  https://maps.gstatic.com/mapfiles/place_api/ic...
# 10  https://maps.gstatic.com/mapfiles/place_api/ic...
# 18  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                             name       opening_hours  \
# 5           MAR Y SOL RESTAURANT  {'open_now': True}
# 22        Green Lotus Restaurant  {'open_now': True}
# 15    Mudai Ethiopian Restaurant  {'open_now': True}
# 21              The Boiling Crab  {'open_now': True}
# 1     Palermo Italian Restaurant  {'open_now': True}
# 20    Minato Japanese Restaurant  {'open_now': True}
# 8                Maza Restaurant  {'open_now': True}
# 11     Gojo Ethiopian Restaurant  {'open_now': True}
# 0       Tasso's Restaurant & Bar  {'open_now': True}
# 4          Crepevine Restaurants  {'open_now': True}
# 13             Karimi Restaurant  {'open_now': True}
# 2        Angelou's Mexican Grill  {'open_now': True}
# 9      Puro Michoacan Restaurant  {'open_now': True}
# 19             Taiwan Restaurant  {'open_now': True}
# 23                    Yuki Sushi  {'open_now': True}
# 17                     Five Guys  {'open_now': True}
# 12  Kategna Ethiopian Restaurant  {'open_now': True}
# 14   TEQUILA'S TAQUERIA SAN JOSE  {'open_now': True}
# 6                      Zona Rosa  {'open_now': True}
# 7         Habana Cuba Restaurant  {'open_now': True}
# 3         Mr. Chau's Restaurants  {'open_now': True}
# 16           Pho Lynn Restaurant  {'open_now': True}
# 10                        Phở Hà  {'open_now': True}
# 18         Restaurante El Conrro  {'open_now': True}
#
#                                                photos  \
# 5   [{'height': 2735, 'html_attributions': ['<a hr...
# 22  [{'height': 3024, 'html_attributions': ['<a hr...
# 15  [{'height': 3024, 'html_attributions': ['<a hr...
# 21  [{'height': 3024, 'html_attributions': ['<a hr...
# 1   [{'height': 3024, 'html_attributions': ['<a hr...
# 20  [{'height': 3024, 'html_attributions': ['<a hr...
# 8   [{'height': 2252, 'html_attributions': ['<a hr...
# 11  [{'height': 2692, 'html_attributions': ['<a hr...
# 0   [{'height': 1000, 'html_attributions': ['<a hr...
# 4   [{'height': 2560, 'html_attributions': ['<a hr...
# 13  [{'height': 3024, 'html_attributions': ['<a hr...
# 2   [{'height': 3024, 'html_attributions': ['<a hr...
# 9   [{'height': 3024, 'html_attributions': ['<a hr...
# 19  [{'height': 666, 'html_attributions': ['<a hre...
# 23  [{'height': 1080, 'html_attributions': ['<a hr...
# 17  [{'height': 3024, 'html_attributions': ['<a hr...
# 12  [{'height': 720, 'html_attributions': ['<a hre...
# 14  [{'height': 2988, 'html_attributions': ['<a hr...
# 6   [{'height': 4032, 'html_attributions': ['<a hr...
# 7   [{'height': 3456, 'html_attributions': ['<a hr...
# 3   [{'height': 3024, 'html_attributions': ['<a hr...
# 16  [{'height': 3024, 'html_attributions': ['<a hr...
# 10  [{'height': 3024, 'html_attributions': ['<a hr...
# 18  [{'height': 2829, 'html_attributions': ['<a hr...
#
#                        place_id  \
# 5   ChIJi7ZXRevNj4AR1SPueCQKGrs
# 22  ChIJ_9rz9irNj4ARwiuzsURtQbM
# 15  ChIJD19wtDHNj4ARsjNXf_k8hG8
# 21  ChIJmWZMuxszjoAR0fXhXB1XNV4
# 1   ChIJw40UG1bLj4ARpK_t0h8GWsI
# 20  ChIJv6Lt-4TMj4ARLZgLz0LCB2g
# 8   ChIJuYh5XojMj4ARNxWDZWNPswU
# 11  ChIJf310hFrLj4ARsQnTYn7il_0
# 0   ChIJc9baB7M0joAR106O589tXdA
# 4   ChIJFzu161czjoARzBag9Mh7BXw
# 13  ChIJedqCrYHLj4ARkRto3lpYLHs
# 2   ChIJySHcKL3Mj4ARVSRHnldFlhU
# 9   ChIJ8XNukTUzjoARAPG9UtAa0YQ
# 19  ChIJs0lTBVkzjoAR2w9E6CG9bv8
# 23  ChIJV6ZAiVczjoARQQWpjuEKm50
# 17  ChIJPVOSSRozjoAR-5V4UL4ryIY
# 12  ChIJ84d05kbLj4AR3ap-zJrzmKc
# 14  ChIJM4TKY7Y0joARlVy1wEOSYXo
# 6   ChIJq8a8EmjLj4AR6i9BcvnWi38
# 7   ChIJuYJQ4VrLj4AR2SC_HS-iUF8
# 3   ChIJuSZyu-TMj4ARMHw5tXzCsDo
# 16  ChIJmewkKj_Lj4ARdY31Ks28vfc
# 10  ChIJKf8DHSvNj4AR2fwFoNiq20w
# 18  ChIJkxPw_vHNj4AR3kWX9y1LFho
#
#                                             plus_code  price_level  rating  \
# 5   {'compound_code': '84WM+X2 San Jose, Californi...            2    4.70
# 22  {'compound_code': '84MW+47 San Jose, Californi...            2    4.60
# 15  {'compound_code': '84G2+8F San Jose, Californi...            2    4.60
# 21  {'compound_code': '843P+38 San Jose, Californi...            2    4.50
# 1   {'compound_code': '83CX+P4 San Jose, Californi...            2    4.50
# 20  {'compound_code': '84X4+WG San Jose, Californi...            2    4.50
# 8   {'compound_code': '9446+MG San Jose, Californi...            1    4.50
# 11  {'compound_code': '83FQ+FM San Jose, Californi...            1    4.50
# 0   {'compound_code': '836M+28 San Jose, Californi...            2    4.50
# 4   {'compound_code': '835X+6Q San Jose, Californi...            2    4.40
# 13  {'compound_code': '934W+83 San Jose, Californi...            2    4.40
# 2   {'compound_code': '84P5+QX San Jose, Californi...            1    4.40
# 9   {'compound_code': '84CC+4Q San Jose, Californi...            2    4.40
# 19  {'compound_code': '8432+XM San Jose, Californi...            2    4.40
# 23  {'compound_code': '834X+XW San Jose, Californi...            2    4.40
# 17  {'compound_code': '842M+QX San Jose, Californi...            2    4.40
# 12  {'compound_code': '83FH+HH San Jose, Californi...            2    4.40
# 14  {'compound_code': '833H+XF San Jose, Californi...            2    4.30
# 6   {'compound_code': '83MP+68 San Jose, Californi...            2    4.30
# 7   {'compound_code': '84J7+39 San Jose, Californi...            2    4.30
# 3   {'compound_code': '944P+CR San Jose, Californi...            1    4.30
# 16  {'compound_code': '83XQ+R4 San Jose, Californi...            1    4.30
# 10  {'compound_code': '84MV+QH San Jose, Californi...            1    4.30
# 18  {'compound_code': '84Q8+R7 San Jose, Californi...            2    4.30
#
#                       reference  \
# 5   ChIJi7ZXRevNj4AR1SPueCQKGrs
# 22  ChIJ_9rz9irNj4ARwiuzsURtQbM
# 15  ChIJD19wtDHNj4ARsjNXf_k8hG8
# 21  ChIJmWZMuxszjoAR0fXhXB1XNV4
# 1   ChIJw40UG1bLj4ARpK_t0h8GWsI
# 20  ChIJv6Lt-4TMj4ARLZgLz0LCB2g
# 8   ChIJuYh5XojMj4ARNxWDZWNPswU
# 11  ChIJf310hFrLj4ARsQnTYn7il_0
# 0   ChIJc9baB7M0joAR106O589tXdA
# 4   ChIJFzu161czjoARzBag9Mh7BXw
# 13  ChIJedqCrYHLj4ARkRto3lpYLHs
# 2   ChIJySHcKL3Mj4ARVSRHnldFlhU
# 9   ChIJ8XNukTUzjoARAPG9UtAa0YQ
# 19  ChIJs0lTBVkzjoAR2w9E6CG9bv8
# 23  ChIJV6ZAiVczjoARQQWpjuEKm50
# 17  ChIJPVOSSRozjoAR-5V4UL4ryIY
# 12  ChIJ84d05kbLj4AR3ap-zJrzmKc
# 14  ChIJM4TKY7Y0joARlVy1wEOSYXo
# 6   ChIJq8a8EmjLj4AR6i9BcvnWi38
# 7   ChIJuYJQ4VrLj4AR2SC_HS-iUF8
# 3   ChIJuSZyu-TMj4ARMHw5tXzCsDo
# 16  ChIJmewkKj_Lj4ARdY31Ks28vfc
# 10  ChIJKf8DHSvNj4AR2fwFoNiq20w
# 18  ChIJkxPw_vHNj4AR3kWX9y1LFho
#
#                                                 types  user_ratings_total  \
# 5   [restaurant, food, point_of_interest, establis...                 149
# 22  [restaurant, point_of_interest, food, establis...                 333
# 15  [restaurant, food, point_of_interest, establis...                 182
# 21  [restaurant, point_of_interest, food, establis...                2354
# 1   [bar, restaurant, food, point_of_interest, est...                1116
# 20  [restaurant, point_of_interest, food, establis...                 649
# 8   [restaurant, food, point_of_interest, establis...                 413
# 11  [restaurant, food, point_of_interest, establis...                 294
# 0   [restaurant, food, point_of_interest, establis...                 280
# 4   [restaurant, food, point_of_interest, establis...                1357
# 13  [restaurant, food, point_of_interest, establis...                 859
# 2   [meal_delivery, meal_takeaway, restaurant, foo...                 627
# 9   [restaurant, food, point_of_interest, establis...                 622
# 19  [restaurant, point_of_interest, food, establis...                 588
# 23  [restaurant, point_of_interest, food, establis...                 571
# 17  [meal_takeaway, restaurant, point_of_interest,...                 528
# 12  [restaurant, food, point_of_interest, establis...                 499
# 14  [restaurant, food, point_of_interest, establis...                2049
# 6   [restaurant, food, point_of_interest, establis...                 892
# 7   [restaurant, food, point_of_interest, establis...                 630
# 3   [restaurant, food, point_of_interest, establis...                 348
# 16  [restaurant, food, point_of_interest, establis...                 252
# 10  [restaurant, food, point_of_interest, establis...                 249
# 18  [restaurant, point_of_interest, food, establis...                 216
#
#     location.lat  location.lng  viewport.northeast.lat  \
# 5          37.35       -121.87                   37.35
# 22         37.33       -121.85                   37.33
# 15         37.33       -121.90                   37.33
# 21         37.30       -121.86                   37.30
# 1          37.32       -121.90                   37.32
# 20         37.35       -121.89                   37.35
# 8          37.36       -121.89                   37.36
# 11         37.32       -121.91                   37.32
# 0          37.31       -121.92                   37.31
# 4          37.31       -121.90                   37.31
# 13         37.36       -121.90                   37.36
# 2          37.34       -121.89                   37.34
# 9          37.32       -121.88                   37.32
# 19         37.30       -121.90                   37.31
# 23         37.31       -121.90                   37.31
# 17         37.30       -121.87                   37.30
# 12         37.32       -121.92                   37.33
# 14         37.30       -121.92                   37.31
# 6          37.33       -121.91                   37.33
# 7          37.33       -121.89                   37.33
# 3          37.36       -121.86                   37.36
# 16         37.35       -121.91                   37.35
# 10         37.33       -121.86                   37.34
# 18         37.34       -121.88                   37.34
#
#     viewport.northeast.lng  viewport.southwest.lat  viewport.southwest.lng
# 5                  -121.87                   37.35                 -121.87
# 22                 -121.85                   37.33                 -121.86
# 15                 -121.90                   37.32                 -121.90
# 21                 -121.86                   37.30                 -121.87
# 1                  -121.90                   37.32                 -121.90
# 20                 -121.89                   37.35                 -121.89
# 8                  -121.89                   37.36                 -121.89
# 11                 -121.91                   37.32                 -121.91
# 0                  -121.92                   37.31                 -121.92
# 4                  -121.90                   37.31                 -121.90
# 13                 -121.90                   37.35                 -121.91
# 2                  -121.89                   37.34                 -121.89
# 9                  -121.88                   37.32                 -121.88
# 19                 -121.90                   37.30                 -121.90
# 23                 -121.90                   37.31                 -121.90
# 17                 -121.86                   37.30                 -121.87
# 12                 -121.92                   37.32                 -121.92
# 14                 -121.92                   37.30                 -121.92
# 6                  -121.91                   37.33                 -121.92
# 7                  -121.89                   37.33                 -121.89
# 3                  -121.86                   37.35                 -121.86
# 16                 -121.91                   37.35                 -121.91
# 10                 -121.85                   37.33                 -121.86
# 18                 -121.88                   37.34                 -121.89

# %% [markdown]
# # v2

# %%
# # Define search parameters
# city_name = 'North San Jose'

# lat = gmaps.places(query=city_name).get('results')[0].get('geometry').get('location').get('lat')
# lng = gmaps.places(query=city_name).get('results')[0].get('geometry').get('location').get('lng')

# search_params = {
#     'location': str(lat)+','+str(lng),  # Define the location you want to search near
#     'radius': 1000,                   # Radius in meters
#     'keyword': 'restaurant',          # Keyword for the search (e.g., 'restaurant')
#     'minprice': 0,                   # Minimum price level
#     'maxprice': 4,                   # Maximum price level
# }

# # Perform the search
# places = gmaps.places_nearby(**search_params)

# # Filter and sort results
# filtered_places = [place for place in places['results'] if place['user_ratings_total'] >= 100 and place['rating'] >= 4.1]
# sorted_places = sorted(filtered_places, key=lambda x: x['name'])  # Sort by restaurant name

# # Display the top 10 results
# top_10_places = sorted_places[:10]
# for place in top_10_places:
#     print(f"Name: {place['name']}, Rating: {place['rating']}, Total Reviews: {place['user_ratings_total']}")
